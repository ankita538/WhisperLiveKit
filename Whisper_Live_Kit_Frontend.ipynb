# %% [markdown]
# <a href="https://colab.research.google.com/github/ankita538/WhisperLiveKit/blob/main/Whisper_Live_Kit_Frontend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/QuentinFuxa/WhisperLiveKit
# Out:
# fatal: destination path 'WhisperLiveKit' already exists and is not an empty directory.

# %%
# !pip install fastapi uvicorn  nest-asyncio faster-whisper
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 91.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.6 MB/s eta 0:00:00
# ...

# %%
# %cd WhisperLiveKit/
# Out:
# /content/WhisperLiveKit

# %%
# !pwd
# Out:
# /content/WhisperLiveKit

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/WhisperLiveKit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for whisperlivekit (pyproject.toml) ... done
#   Created wheel for whisperlivekit: filename=whisperlivekit-0.2.15-0.editable-py3-none-any.whl size=17214 sha256=699742840c36f19ad648bd810ff517ca8973b70d640c98ef4d867507539f0b04
#   Stored in directory: /tmp/pip-ephem-wheel-cache-85b6fkc5/wheels/a3/b5/fc/7fd937085e080b3dda6a2336aa5596de23f3da480a3b71ddd5
# Successfully built whisperlivekit
# ...

# %%
# !pip show whisperlivekit
# Out:
# Name: whisperlivekit
# Version: 0.2.15
# Summary: Real-time speech-to-text with speaker diarization using Whisper
# Home-page: https://github.com/QuentinFuxa/WhisperLiveKit
# Author: Quentin Fuxa
# Author-email:
# License: Apache License
#                            Version 2.0, January 2004
#                         http://www.apache.org/licenses/
#
#    TERMS AND CONDITIONS FOR USE, REPRODUCTION, AND DISTRIBUTION
#
#    1. Definitions.
#
#       "License" shall mean the terms and conditions for use, reproduction,
#       and distribution as defined by Sections 1 through 9 of this document.
#
#       "Licensor" shall mean the copyright owner or entity authorized by
#       the copyright owner that is granting the License.
#
#       "Legal Entity" shall mean the union of the acting entity and all
#       other entities that control, are controlled by, or are under common
#       control with that entity. For the purposes of this definition,
# ...

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("35v6tknibVDDpruJS1iGQkUAoCp_89L3foHJKXjaHJPqaPSyP")

# %%
import nest_asyncio
from pyngrok import ngrok
import uvicorn

nest_asyncio.apply()
public_url = ngrok.connect(8000)
print(f"Public URL: {public_url}")
# Out:
# Public URL: NgrokTunnel: "https://subapprobatory-laura-unjoyfully.ngrok-free.dev" -> "http://localhost:8000"

# %%
# !python -m whisperlivekit.basic_server

# %%
# !grep -Rn "SimulStreamingOnlineProcessor" /content/WhisperLiveKit/
# Out:
# /content/WhisperLiveKit/whisperlivekit/core.py:172:        from whisperlivekit.simul_whisper import SimulStreamingOnlineProcessor
# /content/WhisperLiveKit/whisperlivekit/core.py:173:        online = SimulStreamingOnlineProcessor(asr, lan=client_lan)
# /content/WhisperLiveKit/whisperlivekit/simul_whisper/__init__.py:1:from .backend import SimulStreamingASR, SimulStreamingOnlineProcessor
# /content/WhisperLiveKit/whisperlivekit/simul_whisper/__init__.py:5:    "SimulStreamingOnlineProcessor",
# grep: /content/WhisperLiveKit/whisperlivekit/simul_whisper/__pycache__/__init__.cpython-312.pyc: binary file matches
# grep: /content/WhisperLiveKit/whisperlivekit/simul_whisper/__pycache__/backend.cpython-312.pyc: binary file matches
# /content/WhisperLiveKit/whisperlivekit/simul_whisper/backend.py:39:class SimulStreamingOnlineProcessor:
# grep: /content/WhisperLiveKit/whisperlivekit/__pycache__/core.cpython-312.pyc: binary file matches
